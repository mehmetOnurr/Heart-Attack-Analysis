# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Read Csv File

# %%
# read csv
dataset = pd.read_csv("dataset/heart.csv")

#print dataset
dataset
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %% [markdown]
# ## Information about dataset

# %%
# first 5 row in dataset
dataset.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
# last 5 row in dataset
dataset.tail()
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 298    0      3       0
# 299    0      3       0
# 300    2      3       0
# 301    1      3       0
# 302    1      2       0

# %%
# dataset shape
dataset.shape
# Out:
# (303, 14)

# %%
# dataset column's names
dataset.columns
# Out:
# Index(['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output'],
#       dtype='object')

# %%
# dataset information
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
# dataset describe
dataset.describe()
# Out:
#               age         sex          cp      trtbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
# Null data count for each column in dataset
dataset.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %% [markdown]
# There aren't any non-value in dataset

# %%
# nunique count in dataset
dataset.nunique()
# Out:
# age          41
# sex           2
# cp            4
# trtbps       49
# chol        152
# fbs           2
# restecg       3
# thalachh     91
# exng          2
# oldpeak      40
# slp           3
# caa           5
# thall         4
# output        2
# dtype: int64

# %%
# output column nunique
dataset["output"].nunique()
# Out:
# 2

# %%
# output column count each attribute
dataset["output"].value_counts()
# Out:
# 1    165
# 0    138
# Name: output, dtype: int64

# %% [markdown]
# Plots histograms

# %%
# plot one by one specific columns
for c_name in dataset[["sex","cp","fbs","restecg","exng","slp","caa","thall","output"]]:
    sns.countplot(dataset[c_name],data= dataset,palette='hls')
    plt.title(c_name)
    plt.xticks(rotation= 90)
    plt.show()

# %%
# plot in one figure specific columns
columns_names = ["sex","cp","fbs","restecg","exng","slp","caa","thall","output"]

fig, axes = plt.subplots(3,3,figsize=(30,15))
s=0
for i in range(0,3):
    for j in range(0,3):
        
        if s== 9:
            break
        sns.countplot(ax=axes[i,j],x=columns_names[s],data= dataset,palette='hls')
        axes[i,j].set_title(columns_names[s])
        s+=1
plt.show()

# %%
# plot relation with output
columns_names = ["sex","cp","fbs","restecg","exng","slp","caa","thall","oldpeak","age","trtbps","thalachh","chol"]

fig, axes = plt.subplots(4,3,figsize=(50,23))
s=0

for i in range(0,4):
    for j in range(0,3):
        
        if s== 13:
            break
        sns.countplot(ax=axes[i,j],x=columns_names[s],data= dataset,hue="output")
        axes[i,j].set_title(columns_names[s])
        s+=1
plt.show()

# %%
# plot pie output column
plt.figure(figsize=(15,6))
colors = sns.color_palette("bright")
explode= [0.3,0.02]
plt.pie(dataset["output"].value_counts(),colors=colors,labels=[1,0],autopct='%0.0f%%',shadow='True',explode=explode, startangle=180)
plt.show()

# %%
# plots multi nunique columns

# age column
plt.figure(figsize=(15,6))
sns.countplot(x="age",hue="output",data=dataset)
plt.xticks(rotation=90)
plt.title("age-output")
plt.show()

# chol column
plt.figure(figsize=(50,12))
sns.countplot(x="chol",hue="output",data=dataset)
plt.xticks(rotation=90)
plt.title("chol-output")
plt.show()

# chol column
plt.figure(figsize=(50,12))
sns.countplot(x="thalachh",hue="output",data=dataset)
plt.xticks(rotation=90)
plt.title("thalachh-output")
plt.show()

# chol column
plt.figure(figsize=(30,12))
sns.countplot(x="oldpeak",hue="output",data=dataset)
plt.xticks(rotation=90)
plt.title("oldpeak-output")
plt.show()

# %% [markdown]
# ## Create The Heatmap

# %%
plt.figure(figsize=(15,6))
cmap = sns.diverging_palette(250, 10, s=80,l=55, n=9,as_cmap=True)
sns.heatmap(dataset.corr(),annot=True,cmap=cmap,center=0)
plt.show()

# %% [markdown]
# ## Plots Boxplots

# %%
# Thalachh boxplot
plt.figure(figsize=(15,6))
ax = sns.boxplot(x=dataset["thalachh"])
plt.title("thalachh")
plt.show()

# output based thallachh heatmap
plt.figure(figsize=(30,20))
ax = sns.boxplot(x="output",y= "thalachh",data = dataset)
plt.title("output-thalachh")
plt.show()

# cp heatmap
plt.figure(figsize=(15,6))
ax = sns.boxplot(x=dataset["cp"])
plt.title("cp")
plt.show()

# output based cp heatmap
plt.figure(figsize=(30,20))
ax = sns.boxplot(x="output",y= "cp",data = dataset)
plt.title("output-cp")
plt.show()

# oldpeak heatmap
plt.figure(figsize=(30,20))
ax= sns.boxplot(x=dataset["oldpeak"])
plt.title("oldpeak")
plt.show()

# output based output heatmap
plt.figure(figsize=(30,20))
ax= sns.boxplot(x="output",y= "oldpeak",data=dataset)
plt.title("output-oldpeak")
plt.show()

# %% [markdown]
# ## Clean outliers

# %% [markdown]
# Before used preprocessing standardScale isn't work well.
# Also before used log transform scale processes aren't well.
#
# Tested Preporcessings:
#
# For scale:
#
# * MinMaxScaler
#
# * StandardScaler
#
# For Encode:
#
# * OneHotEncoder

# %%
#%%Using log transformation


dataset["age"]= np.log(dataset.age)
dataset["trtbps"]= np.log(dataset.trtbps)
dataset["chol"]= np.log(dataset.chol)
dataset["thalachh"]= np.log(dataset.thalachh)


#Outliners again
continuous_cols=["age","trtbps","chol","thalachh","oldpeak"]
continuous_data=dataset[continuous_cols]


print("Log Transform performed")

for key, value in continuous_data.items():
        q1 = value.quantile(0.25)
        q3 = value.quantile(0.75)
        irq = q3 - q1
        value_col = value[(value <= q1 - 1.5 * irq) | (value >= q3 + 1.5 * irq)]
        percentage = np.shape(value_col)[0] * 100.0 / np.shape(dataset)[0]
        print("Column name :{} outliers = {} => % {} ".format(key,len(value_col),round((percentage),3)))
        
        
#Data split (X,y)
X=dataset.iloc[:,:13]
y=dataset["output"]

# Libraries
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=65) 

# MinMax Scaling (Normalization) of data
MM_scaler = MinMaxScaler()
X_train = MM_scaler.fit_transform(X_train)
X_test = MM_scaler.fit_transform(X_test)
# Out:
# Log Transform performed
# Column name :age outliers = 1 => % 0.33
# Column name :trtbps outliers = 9 => % 2.97
# Column name :chol outliers = 6 => % 1.98
# Column name :thalachh outliers = 6 => % 1.98
# Column name :oldpeak outliers = 8 => % 2.64

# %% [markdown]
# ## Scale columns and split train & test set

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((242, 13), (61, 13), (242,), (61,))

# %% [markdown]
# ## Deep Learning Solution by using Tensorflow

# %%
#%% import tensorflow 

import tensorflow as tf

# activate gpu

gpus = tf.config.list_physical_devices("GPU")

if gpus:
    
    try:
        gpu = tf.config.set_visible_devices(gpus[0],"GPU")
        logical_device = tf.config.list_logical_devices('GPU')
        print(len(gpus)," Pyhsical device " ,len(logical_device), "Logical device  " )
    except Exception as e:
        print(e)
# Out:
# 1  Pyhsical device  1 Logical device

# %% [markdown]
# ## First Deep Learning Model

# %%
#%% Finded my best deep learning model


# Set random seed
tf.random.set_seed(42)

# Create the model 
model_heart_lognorm_v1 = tf.keras.Sequential([
    tf.keras.layers.Dense(70,activation="relu"),
    tf.keras.layers.Dense(70,activation="relu"),
    
    
    tf.keras.layers.Dense(1,activation="sigmoid")
    ])

# compile the model
model_heart_lognorm_v1.compile(loss = tf.keras.losses.BinaryCrossentropy(),
                       optimizer = tf.keras.optimizers.Adam(lr= 0.002),
                       metrics=["accuracy"])


# Fit the model
history_lognorm_v1 = model_heart_lognorm_v1.fit(X_train,y_train,epochs=50 )

# evaluate model
historyeva = model_heart_lognorm_v1.evaluate(X_test,y_test)
# Out:
# Epoch 1/50
# 8/8 [==============================] - 2s 7ms/step - loss: 0.6582 - accuracy: 0.6860
# Epoch 2/50
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5832 - accuracy: 0.7355
# Epoch 3/50
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5215 - accuracy: 0.7975
# Epoch 4/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4750 - accuracy: 0.8140
# Epoch 5/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4502 - accuracy: 0.7893
# Epoch 6/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4214 - accuracy: 0.8223
# Epoch 7/50
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4026 - accuracy: 0.8264
# Epoch 8/50
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3997 - accuracy: 0.8223
# Epoch 9/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3976 - accuracy: 0.8140
# Epoch 10/50
# ...

# %%
# Find the ideal learning rate

# Set random seed
tf.random.set_seed(42)

# Create the model
model_heart_v5 = tf.keras.Sequential([
    tf.keras.layers.Dense(70,activation="relu"),
    tf.keras.layers.Dense(70,activation="relu"),
    tf.keras.layers.Dense(1,activation="sigmoid")
    ],name="model_heart_v2")

# Compile the model
model_heart_v5.compile(loss= tf.losses.BinaryCrossentropy(),
                       optimizer = tf.keras.optimizers.Adam(),
                       metrics=["accuracy"])

# Create learning rate callbacks
lr_scheduler = tf.keras.callbacks.LearningRateScheduler(lambda epoch : 1e-4 * 10**(epoch/20) )

history_lrRate= model_heart_v5.fit(X_train,y_train,epochs=100,callbacks=[lr_scheduler])
# Out:
# Epoch 1/100
# 8/8 [==============================] - 1s 8ms/step - loss: 0.6868 - accuracy: 0.5826 - lr: 1.0000e-04
# Epoch 2/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.6823 - accuracy: 0.6281 - lr: 1.1220e-04
# Epoch 3/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.6774 - accuracy: 0.6322 - lr: 1.2589e-04
# Epoch 4/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.6726 - accuracy: 0.6240 - lr: 1.4125e-04
# Epoch 5/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6671 - accuracy: 0.6612 - lr: 1.5849e-04
# Epoch 6/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6615 - accuracy: 0.6446 - lr: 1.7783e-04
# Epoch 7/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6552 - accuracy: 0.6570 - lr: 1.9953e-04
# Epoch 8/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6473 - accuracy: 0.6901 - lr: 2.2387e-04
# Epoch 9/100
# ...

# %%
# Plot learning rate history
lrs = 1e-4 * (10**(tf.range(100)/20))
plt.figure(figsize=(10,7))
plt.semilogx(lrs,history_lrRate.history["loss"])
plt.xlabel("Learning Rate")
plt.ylabel("Loss")
plt.title("learning rate vs. Loss");

# %%
# Train with new selected learning rate
# Set random seed
tf.random.set_seed(42)

# Create the model 
model_heart_lognorm_v1 = tf.keras.Sequential([
    tf.keras.layers.Dense(70,activation="relu"),
    tf.keras.layers.Dense(70,activation="relu"),
    
    
    tf.keras.layers.Dense(1,activation="sigmoid")
    ])

# compile the model
model_heart_lognorm_v1.compile(loss = tf.keras.losses.BinaryCrossentropy(),
                       optimizer = tf.keras.optimizers.Adam(lr= 0.003),
                       metrics=["accuracy"])


# Fit the model
history_lognorm_v1 = model_heart_lognorm_v1.fit(X_train,y_train,epochs=50 )

# evaluate model
historyeva = model_heart_lognorm_v1.evaluate(X_test,y_test)
# Out:
# Epoch 1/50
# 8/8 [==============================] - 1s 8ms/step - loss: 0.6436 - accuracy: 0.7149
# Epoch 2/50
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5373 - accuracy: 0.7851
# Epoch 3/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4688 - accuracy: 0.7934
# Epoch 4/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4327 - accuracy: 0.8099
# Epoch 5/50
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4277 - accuracy: 0.8140
# Epoch 6/50
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4046 - accuracy: 0.8264
# Epoch 7/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3839 - accuracy: 0.8430
# Epoch 8/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3868 - accuracy: 0.8140
# Epoch 9/50
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3872 - accuracy: 0.8182
# Epoch 10/50
# ...

# %% [markdown]
# ## Check out Model performans

# %%
# evaluate model
historyeva = model_heart_lognorm_v1.evaluate(X_test,y_test)
# Out:
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2572 - accuracy: 0.9344

# %% [markdown]
#  ## Plots Training Results

# %%
def plot_predictions(model,X,y,figsize=(15,8)):
    
    pred_datas = model.predict(X)
    
    plt.figure(figsize = figsize)
    plt.scatter(range(len(pred_datas)),pred_datas,c="g",marker="X",label="Predictions")
    plt.scatter(range(len(y)),y,c="r",label="Actual")
    plt.legend();
    

plot_predictions( model_heart_lognorm_v1,X_test,y_test,(15,8))
# Out:
# 2/2 [==============================] - 0s 4ms/step

# %%
plot_predictions( model_heart_lognorm_v1,X_train,y_train,(30,17))
# Out:
# 8/8 [==============================] - 0s 3ms/step

# %% [markdown]
# # Machine Learning Solutions

# %% [markdown]
# ## Import Classification Models

# %%
#Dictionary for models
models = {}

# Logistic Regression
from sklearn.linear_model import LogisticRegression
models['logistic_regression'] = LogisticRegression()

# Support Vector Machine
from sklearn.svm import SVC
models['Support Vector Machines'] = SVC()

# Decision Trees
from sklearn.tree import DecisionTreeClassifier
models['decision_trees'] = DecisionTreeClassifier()

# Random Forest
from sklearn.ensemble import RandomForestClassifier
models['random_forest'] = RandomForestClassifier()

# Naive Bayes
from sklearn.naive_bayes import GaussianNB
models['naive_bayes'] = GaussianNB()

# K-Nearest Neighbors
from sklearn.neighbors import KNeighborsClassifier
models['k-nearest_neighbor'] = KNeighborsClassifier()

models
# Out:
# {'logistic_regression': LogisticRegression(),
#  'Support Vector Machines': SVC(),
#  'decision_trees': DecisionTreeClassifier(),
#  'random_forest': RandomForestClassifier(),
#  'naive_bayes': GaussianNB(),
#  'k-nearest_neighbor': KNeighborsClassifier()}

# %% [markdown]
# ## Fit and Test Models

# %%
# Import measurement functions
from sklearn.metrics import accuracy_score, precision_score, recall_score

# Define attributes 
accuracy, precision, recall = {}, {}, {}

prediction_list ={}

# Models training in for loop
for key in models.keys():
    
    # Fit the classifier
    models[key].fit(X_train,y_train)
    
    # Make predictions
    predictions = models[key].predict(X_test)
    
    prediction_list[key] = predictions
    
    # Calculate metrics
    accuracy[key] = accuracy_score(predictions, y_test)
    precision[key] = precision_score(predictions, y_test)
    recall[key] = recall_score(predictions, y_test)

# %% [markdown]
# ## Plot Training Results

# %%
# 
df_model = pd.DataFrame(index=models.keys(), columns=['Accuracy', 'Precision', 'Recall'])
df_model['Accuracy'] = accuracy.values()
df_model['Precision'] = precision.values()
df_model['Recall'] = recall.values()

df_model
# Out:
#                          Accuracy  Precision    Recall
# logistic_regression      0.901639    0.93750  0.882353
# Support Vector Machines  0.901639    0.93750  0.882353
# decision_trees           0.819672    0.78125  0.862069
# random_forest            0.901639    0.87500  0.933333
# naive_bayes              0.901639    0.87500  0.933333
# k-nearest_neighbor       0.901639    0.90625  0.906250

# %%
#%% Customised confusion matrix

import itertools

from sklearn.metrics import confusion_matrix

def make_confusion_matrix(y_true,y_pred,classes = None,figsize=(10,10),text_size=15):
   
    
    # Create the confusion matrix
    cm = confusion_matrix(y_true,y_pred)
    cm_norm = cm.astype("float")/ cm.sum(axis=1)[:,np.newaxis] # normalization
    n_classes = cm.shape[0]
    
  
    
    # Let's prettify it
    fig, ax = plt.subplots(figsize=figsize)
    # Create a matrix plot
    cax = ax.matshow(cm, cmap = plt.cm.Blues)
    fig.colorbar(cax)
    
    
    if classes:
        labels = classes
    else:
        labels = np.arange(cm.shape[0])
    
    # Label the axes
    ax.set(title= " Confusion Matrix ("+key+")",
           xlabel= "Predicted Label",
           ylabel = "True Label",
           xticks = np.arange(n_classes),
           yticks= np.arange(n_classes),
           xticklabels = labels,
           yticklabels= labels)
    
    # Set x-axis labels to bottom
    ax.xaxis.set_label_position("bottom")
    ax.xaxis.tick_bottom()
    
    # adjust label size
    ax.yaxis.label.set_size(text_size)
    ax.xaxis.label.set_size(text_size)
    ax.title.set_size(text_size)
    # Set threshold for different colors
    threshold = (cm.max() + cm.min()) / 2.
    
    # Plot text on each cell
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j,i,f"{cm[i,j]} ({cm_norm[i,j]*100:.1f}%)",
                 horizontalalignment="center",
                 color = "white" if cm[i,j] > threshold else "black",
                 size = text_size)

# %%
for key,value in prediction_list.items():
    make_confusion_matrix(y_test,value,classes = [0,1],figsize=(10,10),text_size=15)
